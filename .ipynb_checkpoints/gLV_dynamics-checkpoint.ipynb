# %% [markdown]
# ### Generalized Lotka-Volterra
#
# $\newcommand{\R}{\mathbb{R}}$
# $\newcommand{\N}{\mathcal{N}}$
# $\newcommand{\ddt}[1]{\dfrac{d #1}{ dt}}$
#
# Following the analysis in *Robust and Scalable Models of Microbiome Dynamics* Gibson and Gerber ICMLR 2018
#
# The gLV equation for a population vector $ x \in \R^+$ are
#
# $$ \ddt{x} = x \cdot (a_{1} + a_{2}x + B x) + \xi.$$
#
# Here $a_1$ is the vector of growth rates, $a_2$ is the vector of "self interactions," $B$ is a matrix of cross species interactions (with all diagonal equal to 0), and $\xi$ is a vector of noise where each element is iid from $\N(0, \sigma_w)$.
#
# Ill write down the model later but the priors for all of these parameters are Normal distributions with a different variance for each set of parameters (i.e. $\sigma_a$, $\sigma_b$). In reality (generally) $a_1 >0$ and $a_2<0$.
#
# This model doesn't include the clustering aspect from the paper but ill cirle back to that. Below ill just sparsify the interaction matrix because that seems sensible.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib as mpl
rc("text", usetex=True)
rc("font", family = "serif")
rc("figure",figsize=(9,6))
rc("figure",facecolor="white")
# %config InlineBackend.figure_format = 'retina'

mpl.style.use('dark_background') #Use a dark background for matplotlib figures if youre using dark theme
plt.rcParams.update({"figure.facecolor": "111111",
                     "savefig.facecolor": "212121"})
import pymc3 as pm

# %%
from scipy import stats

# %% [markdown]
# ### Simulation

# %%
# Some parameters
n_species = 13
interaction_sparsity = 0.4
sigma_a = 3
sigma_b = 2
sigma_w = 0.5

a1 = 20*np.ones(n_species)
a2 = -5*np.ones(n_species)
B = np.diag(a2)

cluster1 = np.array([1,5,7,9,11])-1
cluster2 = np.array([2,4,6,8,10,12])-1
cluster3 = np.array([3,13])-1

b12 = 3
b13 = -1
b31 = 2
b32 = -4

B[np.ix_(cluster1,cluster2)] = b12
B[np.ix_(cluster1,cluster3)] = b13
B[np.ix_(cluster3,cluster1)] = b31
B[np.ix_(cluster3,cluster2)] = b32

disp_order = np.concatenate((cluster1,cluster2,cluster3))


a = 5
loc = 0
scale = 1.5
gamma = stats.gamma(a, loc, scale)
x0 = gamma.rvs(n_species)

# %%
xplt = np.linspace(0,20,200)
plt.plot(xplt, gamma.pdf(xplt))
plt.show()

# %%
#Find self interaction terms that admit a non-negative equilibrium in the non stochastic case of gLV dynamics

max_iters = 1000
iters=0
while np.any(np.linalg.lstsq(B,-a1,rcond=None)[0]<0):
    a1 = 2+sigma_a*np.random.randn(n_species)
    iters += 1
    if iters==max_iters:
        print("Timed out")
        break

# %%
B[cluster1][:,cluster2]
# Out:
# array([[3., 3., 3., 3., 3., 3.],
#        [3., 3., 3., 3., 3., 3.],
#        [3., 3., 3., 3., 3., 3.],
#        [3., 3., 3., 3., 3., 3.],
#        [3., 3., 3., 3., 3., 3.]])

# %%
plt.imshow(B[disp_order][:,disp_order])
plt.colorbar()
plt.show()

# %%
T = 0.25
dt = 0.0025
n_steps = np.int(T/dt)+1
t_plot = np.linspace(0,T,n_steps)
n_reps = 5

X = np.zeros((n_steps, n_species, n_reps))
#B = np.zeros((n_species,n_species))
X[0] = gamma.rvs(X[0].shape)
for t in range(1, n_steps):
    X[t] = X[t-1] + dt*X[t-1]*(a1.reshape(-1,1) + B@X[t-1]) + np.sqrt(dt)*np.random.randn(n_species, n_reps)
    X[t][X[t]<0] = 0

# %%
for r in range(n_reps):
    for i,cluster in enumerate([cluster1, cluster2, cluster3]):
        for species in cluster:
            plt.plot(t_plot, X[:,species, r],color=f'C{i}')
    plt.show()

# %%
N_replicates = 5

xtest = gamma.rvs((n_species,N_replicates))

# %%
out1 = (B@xtest)

# %%
def simulate_glv(n_replicates, T, dt, a, B):
    n_steps = np.int(T/dt)+1
    X = np.zeros((n_steps, n_species, n_replicates))
    X[0] = gamma.rvs(X[0].shape)
    for t in range(1, n_steps):
        X[t] = X[t-1] + dt*X[t-1]*(a.reshape(-1,1) + B@X[t-1]) #+ np.sqrt(dt)*np.random.randn(n_species,n_replicates)
        X[t][X[t]<0] = 0
    return X

# %%
X1 = simulate_glv(5, 0.25, 0.001, a1, B)

# %%
data = X1[np.arange(11)*10]
t_data = np.linspace(0,.25,101)[np.arange(11)*10]

# %%
for i in range(n_species):
    plt.errorbar(t_data, data.mean(-1)[:,i], yerr=data.std(-1)[:,i])
plt.show()

# %%
X2 = simulate_glv(5, .25, .025, a1, B)

# %%
for r in range(n_reps):
    for i,cluster in enumerate([cluster1, cluster2, cluster3]):
        for species in cluster:
            plt.plot(np.arange(11), X2[:,species, r],color=f'C{i}')
plt.show()

# %%
import pyro
import pyro.distributions as dist
from pyro.infer import MCMC, NUTS
from pyro.infer.autoguide import AutoDelta
import torch
from pyro import poutine
torch.set_default_tensor_type(torch.DoubleTensor)

# %%
data_tensor = torch.tensor(data).permute(2,0,1)
time_tensor = torch.tensor(t_data)

# %%
def torch_glv(x0, a, B, T, dt=0.001, dense=True):
    if dense:
        x = torch.zeros((int(T/dt)+1, x0.shape[1], x0.shape[0]))
        x[0] = x0.t()
        for t in range(int(T/dt)):
            x[t+1] = x[t] + dt*x[t]*(a.unsqueeze(1) + B.mm(x[t]))
        return x
    
    else: 
        x = x0.t()
        for t in range(int(T/dt)):
            x = x + dt*x*(a.unsqueeze(1) + B.mm(x))
    
    return x

# %%
x0 = torch.tensor(X1[0]).permute(1,0)

# %%
x0.shape
# Out:
# torch.Size([5, 13])

# %%
Xt1 = torch_glv(x0, torch.tensor(a1), torch.tensor(B), .25)

# %%
print(X1.shape)
print(Xt1.shape)
# Out:
# (251, 13, 5)
# torch.Size([251, 13, 5])

# %%
#for r in range(5):
for s in range(n_species):
    plt.plot(np.linspace(0,.25,251),Xt1[:,s,0], color = 'r')
    plt.plot(np.linspace(0,.25,251),X1[:,s,0], color = 'b')
plt.show()

# %%
def model(tpts,data, n_species, ):
    sigma_a = 3
    sigma_b = 5
    a = pyro.sample('a',dist.Normal(torch.zeros(n_species),3*torch.ones(n_species)).to_event(1))
    sigma_B = sigma_b*(torch.ones((n_species,n_species)) - torch.eye(n_species)) + sigma_a*torch.eye(n_species) 

    B = pyro.sample('B',dist.Normal(torch.zeros((n_species,n_species)),sigma_B).to_event(2))
    with pyro.plate('replicates',data.shape[0]) as r:
        #print(r)
        for t in range(1,data.shape[1]):
        #with pyro.markov()
            x_last = data[r,t-1]
            dt = tpts[t] - tpts[t-1]
            mean = torch_glv(x_last, a, B, dt, dense=False).t()
            #print(mean.shape)
            #print(data[:,t].shape)
            likelihood = dist.Normal(mean, torch.sqrt(dt)*torch.ones_like(mean)).to_event(1)
            #print(likelihood.batch_shape)
            #print(likelihood.event_shape)
            x_t = pyro.sample('x_{}'.format(t), likelihood, obs=data[:,t])

# %%
model(time_tensor,data_tensor)

# %%
trace = poutine.trace(model).get_trace(time_tensor,data_tensor)
trace.compute_log_prob()  # optional, but allows printing of log_prob shapes
print(trace.format_shapes())
# Out:
#   Trace Shapes:
#    Param Sites:
#   Sample Sites:
#          a dist   | 13
#           value   | 13
#        log_prob   |
#          B dist   | 13 13
#           value   | 13 13
#        log_prob   |
# replicates dist   |
#           value 5 |
#        log_prob   |
#        x_1 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_2 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_3 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_4 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_5 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_6 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_7 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_8 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#        x_9 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |
#       x_10 dist 5 | 13
#           value 5 | 13
#        log_prob 5 |

# %%
nuts_kernel = NUTS(model)
mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)

# %%
pyro.clear_param_store()

# %%
mcmc.run(time_tensor,data_tensor)
# Out:
# warmup:   5%|▍         | 56/1200 [07:12, 30.37s/it, step size=3.31e-03, acc. prob=0.797]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-292-0a9e98c3501e> in <module>
# ----> 1 mcmc.run(time_tensor,data_tensor)
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/poutine/messenger.py in _context_wrap(context, fn, *args, **kwargs)
#       6 def _context_wrap(context, fn, *args, **kwargs):
#       7     with context:
# ----> 8         return fn(*args, **kwargs)
#       9
#      10
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     340         z_flat_acc = [[] for _ in range(self.num_chains)]
#     341         with pyro.validation_enabled(not self.disable_validation):
# --> 342             for x, chain_id in self.sampler.run(*args, **kwargs):
#     343                 if num_samples[chain_id] == 0:
#     344                     num_samples[chain_id] += 1
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in run(self, *args, **kwargs)
#     157         hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
#     158         for sample in _gen_samples(self.kernel, self.warmup_steps, self.num_samples, hook_w_logging,
# --> 159                                    *args, **kwargs):
#     160             yield sample, 0  # sample, chain_id (default=0)
#     161         progress_bar.close()
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/api.py in _gen_samples(kernel, warmup_steps, num_samples, hook, *args, **kwargs)
#     110     yield {k: v.shape for k, v in params.items()}
#     111     for i in range(warmup_steps):
# --> 112         params = kernel.sample(params)
#     113         hook(kernel, params, 'warmup', i)
#     114     for i in range(num_samples):
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in sample(self, params)
#     346                 else:  # go the the left, start from the left leaf of current tree
#     347                     new_tree = self._build_tree(z_left, r_left, z_left_grads, log_slice,
# --> 348                                                 direction, tree_depth, energy_current)
#     349                     z_left = new_tree.z_left
#     350                     r_left = new_tree.r_left
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     222             z_grads = half_tree.z_left_grads
#     223         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 224                                            direction, tree_depth-1, energy_current)
#     225
#     226         if self.use_multinomial_sampling:
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     222             z_grads = half_tree.z_left_grads
#     223         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 224                                            direction, tree_depth-1, energy_current)
#     225
#     226         if self.use_multinomial_sampling:
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     222             z_grads = half_tree.z_left_grads
#     223         other_half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 224                                            direction, tree_depth-1, energy_current)
#     225
#     226         if self.use_multinomial_sampling:
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     201         # build the first half of tree
#     202         half_tree = self._build_tree(z, r, z_grads, log_slice,
# --> 203                                      direction, tree_depth-1, energy_current)
#     204         z_proposal = half_tree.z_proposal
#     205         z_proposal_pe = half_tree.z_proposal_pe
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     197     def _build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current):
#     198         if tree_depth == 0:
# --> 199             return self._build_basetree(z, r, z_grads, log_slice, direction, energy_current)
#     200
#     201         # build the first half of tree
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/infer/mcmc/nuts.py in _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#     173         step_size = self.step_size if direction == 1 else -self.step_size
#     174         z_new, r_new, z_grads, potential_energy = velocity_verlet(
# --> 175             z, r, self.potential_fn, self.inverse_mass_matrix, step_size, z_grads=z_grads)
#     176         r_new_flat = torch.cat([r_new[site_name].reshape(-1) for site_name in sorted(r_new)])
#     177         energy_new = potential_energy + self._kinetic_energy(r_new)
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/ops/integrator.py in velocity_verlet(z, r, potential_fn, inverse_mass_matrix, step_size, num_steps, z_grads)
#      32                                                                         inverse_mass_matrix,
#      33                                                                         step_size,
# ---> 34                                                                         z_grads)
#      35     return z_next, r_next, z_grads, potential_energy
#      36
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/ops/integrator.py in _single_step_verlet(z, r, potential_fn, inverse_mass_matrix, step_size, z_grads)
#      50         z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
#      51
# ---> 52     z_grads, potential_energy = potential_grad(potential_fn, z)
#      53     for site_name in r:
#      54         r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pyro/ops/integrator.py in potential_grad(potential_fn, z)
#      81             raise e
#      82
# ---> 83     grads = grad(potential_energy, z_nodes)
#      84     for node in z_nodes:
#      85         node.requires_grad_(False)
#
# /opt/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# KeyboardInterrupt:

# %%
mcmc.get_samples()['a']
# Out:
# tensor([[-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487],
#         [-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487],
#         [-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487],
#         ...,
#         [-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487],
#         [-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487],
#         [-0.4143, -1.6629, -0.7314,  ...,  1.1453, -0.4798,  0.2487]])
